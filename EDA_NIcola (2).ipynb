# %% [markdown]
# #DMML2020 - Project
# ![mod-fr-logo.png](data:image/png;base64,...)
# ##Classification problem
# In this project we analyze the data to know if a tweet is about a real disaster (target = 1) or not (target = 0).
#
#
# In this first iteration we just fit the training data in the Logistic regression and observe the accuracy.

# %%
# Install and update spaCy
# !pip install -U spacy

# Download the english language model
# !python -m spacy download en
# Out:
# Collecting spacy
#   Downloading https://files.pythonhosted.org/packages/50/b2/12466d3018bb84b039139ef76436ea7a01e98125c2aee6a81e527eb4ebe1/spacy-2.3.4-cp36-cp36m-manylinux2014_x86_64.whl (10.4MB)
#      |████████████████████████████████| 10.4MB 4.3MB/s
# Requirement already satisfied, skipping upgrade: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.0.4)
# Requirement already satisfied, skipping upgrade: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.0.0)
# Requirement already satisfied, skipping upgrade: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy) (2.0.4)
# Requirement already satisfied, skipping upgrade: blis<0.8.0,>=0.4.0; python_version >= "3.6" in /usr/local/lib/python3.6/dist-packages (from spacy) (0.4.1)
# Collecting thinc<7.5.0,>=7.4.1
#   Downloading https://files.pythonhosted.org/packages/1b/c9/ce2e03720a5647fd90da575325376ff258653a05f357aa970fd87e6c1a55/thinc-7.4.3-cp36-cp36m-manylinux2014_x86_64.whl (1.1MB)
#      |████████████████████████████████| 1.1MB 34.9MB/s
# Requirement already satisfied, skipping upgrade: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (0.8.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.18.5)
# Requirement already satisfied, skipping upgrade: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (2.23.0)
# Requirement already satisfied, skipping upgrade: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.0.4)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy) (50.3.2)
# Requirement already satisfied, skipping upgrade: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy) (3.0.4)
# Requirement already satisfied, skipping upgrade: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (4.41.1)
# Requirement already satisfied, skipping upgrade: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied, skipping upgrade: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy) (2.0.0)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.11.8)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy) (3.4.0)
# Installing collected packages: thinc, spacy
#   Found existing installation: thinc 7.4.0
#     Uninstalling thinc-7.4.0:
#       Successfully uninstalled thinc-7.4.0
#   Found existing installation: spacy 2.2.4
#     Uninstalling spacy-2.2.4:
#       Successfully uninstalled spacy-2.2.4
# Successfully installed spacy-2.3.4 thinc-7.4.3
# Collecting en_core_web_sm==2.3.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz (12.0MB)
#      |████████████████████████████████| 12.1MB 3.7MB/s
# Requirement already satisfied: spacy<2.4.0,>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from en_core_web_sm==2.3.1) (2.3.4)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (4.41.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.18.5)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.1.3)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.0.4)
# Requirement already satisfied: thinc<7.5.0,>=7.4.1 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (7.4.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.23.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.4.0; python_version >= "3.6" in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (0.4.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (50.3.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (3.0.4)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.0.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2020.11.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (3.0.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (3.4.0)
# Building wheels for collected packages: en-core-web-sm
#   Building wheel for en-core-web-sm (setup.py) ... done
#   Created wheel for en-core-web-sm: filename=en_core_web_sm-2.3.1-cp36-none-any.whl size=12047109 sha256=922244c3c75e605db8a1a12e09bb54c39047b9d388fb970b66a0b1fd7201f693
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2q_dm6m7/wheels/2b/3f/41/f0b92863355c3ba34bb32b37d8a0c662959da0058202094f46
# Successfully built en-core-web-sm
# Installing collected packages: en-core-web-sm
#   Found existing installation: en-core-web-sm 2.2.5
#     Uninstalling en-core-web-sm-2.2.5:
#       Successfully uninstalled en-core-web-sm-2.2.5
# Successfully installed en-core-web-sm-2.3.1
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /usr/local/lib/python3.6/dist-packages/en_core_web_sm -->
# /usr/local/lib/python3.6/dist-packages/spacy/data/en
# You can now load the model via spacy.load('en')

# %%
# !pip install plotly 
# !pip install cufflinks
# !pip install textblob
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.6/dist-packages (4.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from plotly) (1.15.0)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.6/dist-packages (from plotly) (1.3.3)
# Requirement already satisfied: cufflinks in /usr/local/lib/python3.6/dist-packages (0.17.3)
# Requirement already satisfied: plotly>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from cufflinks) (4.4.1)
# Requirement already satisfied: colorlover>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from cufflinks) (0.3.0)
# Requirement already satisfied: pandas>=0.19.2 in /usr/local/lib/python3.6/dist-packages (from cufflinks) (1.1.4)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from cufflinks) (1.15.0)
# Requirement already satisfied: setuptools>=34.4.1 in /usr/local/lib/python3.6/dist-packages (from cufflinks) (50.3.2)
# Requirement already satisfied: numpy>=1.9.2 in /usr/local/lib/python3.6/dist-packages (from cufflinks) (1.18.5)
# Requirement already satisfied: ipython>=5.3.0 in /usr/local/lib/python3.6/dist-packages (from cufflinks) (5.5.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.6/dist-packages (from cufflinks) (7.5.1)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.6/dist-packages (from plotly>=4.1.1->cufflinks) (1.3.3)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.19.2->cufflinks) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.19.2->cufflinks) (2.8.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from ipython>=5.3.0->cufflinks) (4.4.2)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython>=5.3.0->cufflinks) (4.8.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from ipython>=5.3.0->cufflinks) (0.7.5)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.6/dist-packages (from ipython>=5.3.0->cufflinks) (1.0.18)
# Requirement already satisfied: pygments in /usr/local/lib/python3.6/dist-packages (from ipython>=5.3.0->cufflinks) (2.6.1)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.6/dist-packages (from ipython>=5.3.0->cufflinks) (4.3.3)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.6/dist-packages (from ipython>=5.3.0->cufflinks) (0.8.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.6/dist-packages (from ipywidgets>=7.0.0->cufflinks) (4.10.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /usr/local/lib/python3.6/dist-packages (from ipywidgets>=7.0.0->cufflinks) (3.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.6/dist-packages (from ipywidgets>=7.0.0->cufflinks) (5.0.8)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.6/dist-packages (from pexpect; sys_platform != "win32"->ipython>=5.3.0->cufflinks) (0.6.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=5.3.0->cufflinks) (0.2.5)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.2->ipython>=5.3.0->cufflinks) (0.2.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.6/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (5.3.5)
# Requirement already satisfied: tornado>=4.0 in /usr/local/lib/python3.6/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (5.1.1)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.6/dist-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (5.3.1)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (4.7.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (2.6.0)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.6/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (20.0.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (5.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (2.11.2)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.5.0)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.9.1)
# Requirement already satisfied: bleach in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (3.2.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.4.3)
# Requirement already satisfied: testpath in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.4.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.3)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.6.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.1.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.6/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.5.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (20.4)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (2.4.7)
# Requirement already satisfied: textblob in /usr/local/lib/python3.6/dist-packages (0.15.3)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.6/dist-packages (from textblob) (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from nltk>=3.1->textblob) (1.15.0)

# %%
# !pip install chart_studio
# Out:
# Collecting chart_studio
#   Downloading https://files.pythonhosted.org/packages/ca/ce/330794a6b6ca4b9182c38fc69dd2a9cbff60fd49421cb8648ee5fee352dc/chart_studio-1.1.0-py3-none-any.whl (64kB)
#      |████████████████████████████████| 71kB 5.3MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from chart_studio) (1.15.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.6/dist-packages (from chart_studio) (4.4.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from chart_studio) (2.23.0)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.6/dist-packages (from chart_studio) (1.3.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->chart_studio) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->chart_studio) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->chart_studio) (2020.11.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->chart_studio) (1.24.3)
# Installing collected packages: chart-studio
# Successfully installed chart-studio-1.1.0

# %%
# Import required packages
import spacy
from spacy import displacy
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import pandas as pd

# %%
# Import additional packages
from sklearn.base import TransformerMixin
from sklearn.pipeline import Pipeline
import string
from spacy.lang.en.stop_words import STOP_WORDS
from spacy.lang.en import English
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import plotly as py
import cufflinks as cf 
from plotly.offline import iplot

# %%
#Reading the dataframe to build our model
df_train = pd.read_csv("https://raw.githubusercontent.com/98bao/Migros/main/data/training_data.csv")
df_train.head(30)
# Out:
#        id  ... target
# 0    3738  ...      0
# 1     853  ...      0
# 2   10540  ...      1
# 3    5988  ...      1
# 4    6328  ...      1
# 5    6669  ...      1
# 6    9772  ...      0
# 7   10361  ...      0
# 8    1953  ...      0
# 9    9586  ...      1
# 10   8010  ...      1
# 11   7725  ...      0
# 12   9221  ...      1
# 13   1774  ...      1
# 14   8621  ...      0
# 15   1710  ...      1
# 16   4511  ...      0
# 17   1480  ...      0
# 18  10628  ...      1
# 19   7849  ...      0
# 20  10195  ...      1
# 21   1146  ...      0
# 22   9195  ...      1
# 23   1799  ...      0
# 24   3682  ...      0
# 25   3855  ...      1
# 26   1815  ...      1
# 27    256  ...      0
# 28    455  ...      0
# 29   7136  ...      0
#
# [30 rows x 5 columns]

# %%
#Reading dataframe which is going to be tested
df_test = pd.read_csv("https://raw.githubusercontent.com/98bao/Migros/main/data/test_data.csv")
df_test.head(5)
# Out:
#      id  ...                                               text
# 0  9972  ...  Crptotech tsunami and banks.\n http://t.co/KHz...
# 1  9865  ...  I'm that traumatised that I can't even spell p...
# 2  1937  ...  @foxnewsvideo @AIIAmericanGirI @ANHQDC So ... ...
# 3  3560  ...  Me watching Law &amp; Order (IB: @sauldale305)...
# 4  2731  ...                  Papi absolutely crushed that ball
#
# [5 rows x 4 columns]

# %%
#Reading the sample submission
sample_submission = pd.read_csv("https://raw.githubusercontent.com/98bao/Migros/main/data/sample_submission.csv")

# %%
df_train['text'].sample(30)
# Out:
# 929                       Add Familia to the arson squad.
# 2462    @RobertHarding @RepJohnKatko Crazy to use the ...
# 5046    I made a friend more interesting than all of y...
# 2645    Rory McIlroy to Test Ankle Injury in Weekend P...
# 2194    Well so much for outdoor postering @calgaryfri...
# 1115    @GodOf_Mischief_ -of Loki's daggers she pulled...
# 1439                                   I see a massacre!!
# 3332    USA TODAY: .@FedEx will no longer to transport...
# 6129    You wrecked me. Never felt so low in my life. ...
# 6452                    @Freegeezy17 you stay in Houston?
# 3585    Which is true to an extent. The obliteration o...
# 3372          @Uptown_Jorge head up like yo nose bleeding
# 882     Heard #SKH on the radio for the first time. Al...
# 2139    #Sismo M 1.9 - 5km S of Volcano Hawaii: Time20...
# 1035    OMFG??\nDidnt expect Drag Me Down to be the fi...
# 1185            @Jones94Kyle oh fuck sake he is dead ????
# 5581    Baltimore City : I-95 NORTH AT MP 54.8 (FORT M...
# 5539    @RedCoatJackpot *As it was typical for them th...
# 1028    Wreckage 'Conclusively Confirmed' as From MH37...
# 219     #CCOT #TCOT #radiation Nuclear Emergency Track...
# 2458    @KMacTWN @meaganerd Looks like a bowl of weath...
# 4107    Anyone need a P/U tonight? I play Hybrid Slaye...
# 720     Literally trapped in my room Cuz my bathroom b...
# 1898    Tram travellers evacuated after powerlines com...
# 1612                        Drunk twister is so hard ????
# 2134    So when you're caught in a landslide\nI'll be ...
# 672                   To ouvindo sleeping with sirens awn
# 3821    hermancranston: WIRED : Reddit will now quaran...
# 5513    There is this old lady rockin out to death met...
# 2951    @davidolszak or the rioting in happy valley af...
# Name: text, dtype: object

# %% [markdown]
# # Explanatory Data Analysis
# 1. Base rate
# 2. shape of data
# 3. Null Values
# 4. Types of data
# 5. Location
# 6. Text
# 7. List item

# %%
# Import required packages
import gensim
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import bs4 as bs
import urllib.request
import spacy
import string
import math
from gensim.models import Word2Vec
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print("df_train shape:", df_train.shape)
print("df_test shape:", df_test.shape)
test_rate =df_test.shape[0]/df_train.shape[0]
print("Test-train rate:", test_rate)
# Out:
# df_train shape: (6471, 5)
# df_test shape: (1142, 4)
# Test-train rate: 0.17647967856590943

# %% [markdown]
# ####1. Base Rate
# This indicate how often the most common value appears in the dataframe. We have to obtain an accuracy that is superior to the base rate to say that our classifier is well made

# %%
# Number of tweets in df_train  that support or not a real disaster 
Tweets_support = len(df_train[df_train['target'] == 1])
Tweets_does_not_support = len(df_train[df_train['target'] == 0])
print("Number of tweets that does not support a real disaster : ", Tweets_does_not_support)
print("Number of tweets that support a real disaster:", Tweets_support)
# Out:
# Number of tweets that does not support a real disaster :  3701
# Number of tweets that support a real disaster: 2770

# %%
#Base rate of the train df
r = df_train['target'].value_counts() /len(df_train) 
print("Base rate =", max(r))
# Out:
# Base rate = 0.5719363313243703

# %%
#shape of data 
print("Shape of data:", df_train.shape)
print ("Number of Rows:", df_train.shape[0])
print ("Number of Columns", df_train.shape[1])
# Out:
# Shape of data: (6471, 5)
# Number of Rows: 6471
# Number of Columns 5

# %%
# Name of columns
df_train.columns
# Out:
# Index(['id', 'keyword', 'location', 'text', 'target'], dtype='object')

# %%
#Info 
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6471 entries, 0 to 6470
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        6471 non-null   int64
#  1   keyword   6416 non-null   object
#  2   location  4330 non-null   object
#  3   text      6471 non-null   object
#  4   target    6471 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 252.9+ KB

# %%
# Null values 
df_train.isnull().sum()
# Out:
# id             0
# keyword       55
# location    2141
# text           0
# target         0
# dtype: int64

# %%
# Total number of word 
print("Total Number of Words:", df_train['text'].apply(lambda x: len(x.split(' '))).sum())
# Total number of word test_set
print("Total Number of Words test set:", df_test['text'].apply(lambda x: len(x.split(' '))).sum())
# Out:
# Total Number of Words: 96544
# Total Number of Words test set: 17110

# %%
# Sample train_set and test_set
print("Train set sample:", df_train['text'].sample().values[0])
print("Test set sample:", df_test['text'].sample().values[0])
# Out:
# Train set sample: @NigelTanner1 Believe it or not we've had too MUCH rain here. Our newly planted maple trees are actually drowning.
# Test set sample: Enjoying a little golf this summer? Take care to avoid injury -- back and shoulder injuries can happen quickly http://t.co/f1R5ISBVks

# %% [markdown]
# ####4 Exploring locations
# As we can see there are many rows with Nan value or an unclear location name. We have to remember to drop Nan rows if we want to use location for the logistic regression.

# %%
df_train['location']
# Out:
# 0                         USA
# 1                         NaN
# 2       Palm Beach County, FL
# 3                         USA
# 4                  Australia
#                 ...
# 6466                ARGENTINA
# 6467                      NaN
# 6468                      NaN
# 6469           Beirut/Toronto
# 6470                      NaN
# Name: location, Length: 6471, dtype: object

# %%
# Numbr of location
loc_len =len(df_train['location'].unique())
print("Number of locations:", loc_len)
# Out:
# Number of locations: 2922

# %%
# group df_train by location 
my_df_train_group_by_location = df_train.groupby('location').head(1).sort_values('location')
location_list= my_df_train_group_by_location['location']
number_of_location= len(location_list)
print('Number of location:', number_of_location)
print(location_list)
# Out:
# Number of location: 2922
# 5960                          Glasgow
# 1870              Melbourne, Australia
# 4332                              News
# 4819                               å_
# 4258     45å¡ 5'12.53N   14å¡ 7'24.93E
#                      ...
# 6186     ÌøåÀå_T: 40.736324,-73.990062
# 730                    å_: ?? ÌÑ ? : ?
# 2062              å_å_Los Mina Cityã¢
# 5296                å¡å¡Midwest Û¢Û¢
# 1                                  NaN
# Name: location, Length: 2922, dtype: object

# %%
# If we want to use location for the regression we have to clean the text and drop Nan values.:)

# %% [markdown]
# #### 6.Tweets
# In this chapter We want to analyse most frequent words both in tweets that support real disaster and in those that does not support it.

# %%
# We begin by grouping text message by target 
df_train_grouped =df_train[['target','text']].groupby(by='target').agg(lambda x: ' '.join(x))
corpus = df_train_grouped['text']
print(corpus)
# Out:
# target
# 0    Black Eye 9: A space battle occurred at Star O...
# 1    Reality Training: Train falls off elevated tra...
# Name: text, dtype: object

# %%
corpus0 = corpus[[0]]
corpus1 = corpus[[1]]

# %%
# Now we create a funcion in order to find the most common words
def get_top_n_words(corpus, n=None):
    vec = CountVectorizer().fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in     vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

# %%
Whole_tweets_most_common_words = get_top_n_words(corpus, 10)
print(Whole_tweets_most_common_words)
# Out:
# [('co', 4038), ('http', 3663), ('the', 2755), ('in', 1687), ('to', 1649), ('of', 1547), ('and', 1189), ('is', 811), ('you', 769), ('for', 754)]

# %%
Tweets_0_most_common_words = get_top_n_words(corpus0, 30)
Tweets_1_most_common_words = get_top_n_words(corpus1, 30)
print("Corpus 0 :", Tweets_0_most_common_words)
print("Corpus 1 :", Tweets_1_most_common_words)
# Out:
# Corpus 0 : [('co', 1892), ('http', 1645), ('the', 1600), ('to', 998), ('and', 762), ('of', 754), ('in', 700), ('you', 642), ('is', 513), ('my', 479), ('it', 454), ('for', 416), ('on', 370), ('that', 345), ('with', 333), ('this', 248), ('https', 239), ('be', 235), ('me', 233), ('by', 219), ('have', 207), ('so', 206), ('like', 206), ('just', 204), ('are', 201), ('your', 198), ('at', 195), ('was', 189), ('but', 188), ('amp', 176)]
# Corpus 1 : [('co', 2146), ('http', 2018), ('the', 1155), ('in', 987), ('of', 793), ('to', 651), ('and', 427), ('on', 366), ('for', 338), ('is', 298), ('at', 256), ('by', 246), ('from', 206), ('it', 204), ('that', 176), ('with', 163), ('after', 157), ('this', 154), ('fire', 151), ('û_', 145), ('as', 145), ('was', 144), ('are', 140), ('you', 127), ('news', 122), ('have', 122), ('my', 118), ('amp', 118), ('https', 116), ('up', 112)]

# %%
df1 = pd.DataFrame(Tweets_1_most_common_words, columns= ['Token', 'Frequency'])
df0 = pd.DataFrame(Tweets_0_most_common_words, columns= ['Token', 'Frequency'])

# %%
# Most frequent 10 words in tweets that support real disaster 
def barchart_most_frequent_words(data, title):
    plt.style.use('dark_background')
    token= data['Token']
    frequency = data['Frequency']
    plt.bar(token, frequency)
    plt.title(title)
    plt.xlabel('Most frequent Words')
    plt.ylabel('Frequency')
    return plt.show()

# %%
plt.rcParams['figure.figsize']= (30, 5)

# %%
# Barchart Most important word 
barchart_most_frequent_words(df1, 'Most frequent words in Tweets that support real disaster')
barchart_most_frequent_words (df0, 'Most frequent words in Tweets that does not support real disaster')

# %%
Whole_words = get_top_n_words(corpus)
print(f"Number of strings: {len(Whole_words)}")
print(f"Number of unique strings: {len(set(Whole_words))}")
# Out:
# Number of strings: 19330
# Number of unique strings: 19330

# %%
Corpus0_word = get_top_n_words(corpus0)
corpus1_word = get_top_n_words(corpus1)
print(f"Number of strings in corpus0: {len(Corpus0_word)}")
print(f"Number of strings in corpus1: {len(corpus1_word)}")
# Out:
# Number of strings in corpus0: 12770
# Number of strings in corpus1: 10237

# %%
# Here I wanted to do a word Clouds with most common words but i did not get how to do it 
# Importing wordcloud for plotting word clouds and textwrap for wrapping longer text
from wordcloud import WordCloud
from textwrap import wrap

# Function for generating word clouds
def generate_wordcloud(data,title):
  wc = WordCloud(width=400, height=330, max_words=3,colormap="Dark2").generate_from_frequencies(data)
  plt.figure(figsize=(10,8))
  plt.imshow(wc, interpolation='bilinear')
  plt.axis("off")
  plt.title('\n'.join(wrap(title,60)),fontsize=13)
  plt.show()

# %%
# Using CountVectorizer
vectorizer = CountVectorizer()
bag_of_words = vectorizer.fit_transform(corpus).todense()
bag_of_words
# Out:
# matrix([[ 8,  2,  0, ...,  0,  0,  0],
#         [20,  1,  1, ...,  1,  1,  1]])

# %%
print(f"Number of strings: {len(bag_of_words)}")
print(f"Number of unique strings (word): {len(set(bag_of_words))}")
# Out:
# Number of strings: 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-febd9d6b6994> in <module>()
#       1 print(f"Number of strings: {len(bag_of_words)}")
# ----> 2 print(f"Number of unique strings (word): {len(set(bag_of_words))}")
#
# TypeError: unhashable type: 'matrix'

# %%
bow0 = bag_of_words[0]
bow1= bag_of_words[1]

# %%
# Features
vectorizer.vocabulary_
# Out:
# {'black': 2785,
#  'eye': 6324,
#  'space': 15711,
#  'battle': 2443,
#  'occurred': 12192,
#  'at': 2089,
#  'star': 15899,
#  'o784': 12138,
#  'involving': 8921,
#  'fleets': 6724,
#  'totaling': 17044,
#  '3945': 503,
#  'ships': 15236,
#  'with': 18465,
#  '17': 194,
#  'destroyed': 5081,
#  'world': 18563,
#  'fedex': 6522,
#  'no': 11910,
#  'longer': 10387,
#  'to': 16959,
#  'transport': 17135,
#  'bioterror': 2739,
#  'germs': 7263,
#  'in': 8684,
#  'wake': 18109,
#  'of': 12221,
#  'anthrax': 1815,
#  'lab': 9906,
#  'mishaps': 11162,
#  'http': 8320,
#  'co': 4029,
#  '5zdbtktww7': 781,
#  'billionaires': 2720,
#  'have': 7894,
#  'plan': 13074,
#  'free': 6932,
#  'half': 7784,
#  'billion': 2718,
#  'dollars': 5384,
#  'trapped': 17141,
#  'venezuela': 17843,
#  'for': 6815,
#  'two': 17348,
#  'years': 18926,
#  'blakeschmidt': 2799,
#  'reports': 14202,
#  'gbqtc7sp9c': 7204,
#  'jamesmelville': 9113,
#  'some': 15637,
#  'old': 12318,
#  'testimony': 16633,
#  'weapons': 18241,
#  'used': 17674,
#  'promote': 13436,
#  'conflicts': 4237,
#  'tactics': 16403,
#  'corruption': 4365,
#  'amp': 1724,
#  'infiltration': 8768,
#  'groups': 7600,
#  'https': 8321,
#  'cyu8zxw1oh': 4673,
#  'ali': 1620,
#  'you': 19011,
#  'flew': 6728,
#  'planes': 13076,
#  'and': 1745,
#  'ran': 13881,
#  'into': 8892,
#  'burning': 3239,
#  'buildings': 3202,
#  'why': 18382,
#  'are': 1933,
#  'making': 10661,
#  'soup': 15691,
#  'that': 16677,
#  'man': 10678,
#  'child': 3777,
#  'booradleyvancullen': 2950,
#  'my': 11550,
#  'dad': 4706,
#  'is': 8977,
#  'panicking': 12678,
#  'as': 2014,
#  'weight': 18272,
#  'loss': 10423,
#  'means': 10880,
#  'he': 7931,
#  'needs': 11731,
#  'hurry': 8385,
#  'up': 17607,
#  'new': 11772,
#  'clothes': 3986,
#  'fundwhen': 7041,
#  'reach': 13960,
#  'goal': 7420,
#  'thanks': 16674,
#  'benson': 2615,
#  'clegg': 3940,
#  'the': 16686,
#  'follow': 6790,
#  'check': 3739,
#  'out': 12511,
#  'our': 12508,
#  'maps': 10717,
#  'btdjgwekqx': 3167,
#  'god': 7426,
#  'forbid': 6819,
#  'anyone': 1834,
#  'family': 6418,
#  'knows': 9769,
#  'how': 8277,
#  'answer': 1806,
#  'phone': 12966,
#  'need': 11727,
#  'emergency': 5907,
#  'contacts': 4278,
#  'micom': 11054,
#  '2015': 314,
#  'summer': 16182,
#  'contrast': 4296,
#  'candy': 3427,
#  'color': 4106,
#  'bowknot': 2990,
#  'cross': 4523,
#  'body': 2912,
#  'tote': 17048,
#  'shoulder': 15275,
#  'bags': 2332,
#  'womengirls': 18529,
#  'zip': 19177,
#  'po': 13158,
#  'sqmtkkjimj': 15829,
#  'reddit': 14050,
#  'content': 4285,
#  'policy': 13181,
#  'goes': 7433,
#  'effect': 5788,
#  'many': 10710,
#  'horrible': 8242,
#  'subreddits': 16139,
#  'banned': 2373,
#  'or': 12436,
#  'quarantined': 13724,
#  'ohbv7yvtl5': 12269,
#  'ymuti3nd9r': 18988,
#  'thda': 16685,
#  'kicks': 9645,
#  'off': 12229,
#  'anti': 1817,
#  'blight': 2832,
#  'loan': 10338,
#  'effort': 5792,
#  'memphis': 10945,
#  'xzlrwc0pik': 18854,
#  'o5xlxmkoyq': 12133,
#  'fire': 6648,
#  'hazard': 7907,
#  'associated': 2073,
#  'installation': 8829,
#  'non': 11935,
#  'compliant': 4192,
#  'external': 6310,
#  'cladding': 3909,
#  'on': 12351,
#  'high': 8083,
#  'rise': 14409,
#  'insurance': 8844,
#  'aust': 2169,
#  'wfseaobato': 18318,
#  'me': 10873,
#  'all': 1630,
#  'friends': 6974,
#  'could': 4386,
#  'destroy': 5079,
#  'this': 16785,
#  '2hours': 393,
#  'lmao': 10322,
#  'wactt18gda': 18095,
#  'nanotech': 11631,
#  'device': 5115,
#  'will': 18406,
#  'be': 2498,
#  'able': 1272,
#  'target': 16461,
#  'blood': 2855,
#  'clots': 3989,
#  'hfy5v3slbb': 8056,
#  'rt': 14608,
#  'ophiuchus2613': 12407,
#  'love': 10439,
#  'truelove': 17241,
#  'romance': 14518,
#  'lith': 10276,
#  'voodoo': 18015,
#  'seduction': 15016,
#  'astrology': 2083,
#  'rtrrt': 14614,
#  'lotz': 10429,
#  '11': 126,
#  'apocalypse': 1863,
#  'armageddon': 1964,
#  '1008pla': 102,
#  'û_': 19280,
#  'lot': 10426,
#  '20': 296,
#  'tom': 16987,
#  'clancy': 3918,
#  'military': 11093,
#  'mystery': 11569,
#  'novels': 12006,
#  'paperback': 12691,
#  'obix79ncxn': 12163,
#  'tomclancy': 16991,
#  'petition': 12916,
#  'remaster': 14143,
#  'fatal': 6461,
#  'frame': 6910,
#  'windwaker': 18431,
#  'style': 16122,
#  'selfie': 15048,
#  'mode': 11262,
#  'restore': 14274,
#  'vinyl': 17935,
#  'siding': 15316,
#  'make': 10656,
#  'it': 9002,
#  'look': 10392,
#  'again': 1485,
#  'mhl7pfr7kb': 11035,
#  'lou8lbla1f': 10431,
#  'bluedio': 2879,
#  'turbine': 17296,
#  'hurricane': 8382,
#  'bluetooth': 2884,
#  'wireless': 18452,
#  'stereo': 15964,
#  'headphones': 7941,
#  'headset': 7944,
#  'blk': 2845,
#  'full': 7032,
#  're': 13956,
#  'weudlkc4o4': 18308,
#  'trl1dskf81': 17214,
#  'small': 15518,
#  'bag': 2327,
#  'from': 6984,
#  'bottom': 2973,
#  'wounded': 18591,
#  'hero': 8034,
#  'shakes': 15159,
#  'senzu': 15077,
#  'bean': 2505,
#  'falls': 6409,
#  'gohan': 7436,
#  'ûªs': 19297,
#  'surprised': 16257,
#  'pouch': 13250,
#  'once': 12353,
#  'more': 11339,
#  'but': 3260,
#  'let': 10135,
#  'fraction': 6906,
#  'vital': 17967,
#  'fatalities': 6462,
#  'would': 18587,
#  'break': 3050,
#  'down': 5442,
#  'education': 5769,
#  'econom': 5738,
#  'zsqm8ihe1k': 19238,
#  'savannahross_4': 14858,
#  'see': 15017,
#  'tryna': 17255,
#  'ruin': 14631,
#  'life': 10194,
#  'awwww': 2240,
#  'baby': 2298,
#  'walter': 18125,
#  'rewatchingthepilot': 14325,
#  'teamscorpion': 16538,
#  'cyclone': 4666,
#  'fair': 6394,
#  'enough': 6001,
#  'we': 18230,
#  'best': 2628,
#  'attacking': 2120,
#  'wingers': 18438,
#  'prem': 13314,
#  'willian': 18410,
#  'who': 18367,
#  'basically': 2423,
#  'start': 15911,
#  'every': 6186,
#  'game': 7145,
#  '100': 97,
#  'fear': 6511,
#  'factory': 6380,
#  'december': 4886,
#  'done': 5401,
#  'deal': 4859,
#  'tracy': 17099,
#  'thank': 16669,
#  'following': 6795,
#  'so': 15586,
#  'band': 2358,
#  'playing': 13101,
#  'bbcintroducing': 2463,
#  'purpleturtlerdg': 13568,
#  'wednesday': 18259,
#  'giantgiantsound': 7314,
#  'ofan6dkoez': 12224,
#  'rdg': 13952,
#  'former': 6847,
#  'township': 17073,
#  'truck': 17236,
#  'being': 2574,
#  'philippines': 12957,
#  'langley': 9958,
#  'times': 16887,
#  'imilsfxntf': 8636,
#  'filipino': 6610,
#  'omega': 12342,
#  'men': 10946,
#  'writer': 18633,
#  'explores': 6285,
#  'terrorism': 16621,
#  'religion': 14134,
#  'an': 1733,
#  'epic': 6045,
#  'kyle': 9869,
#  'rayner': 13928,
#  'story': 16028,
#  'utc7pdidfo': 17700,
#  'via': 17882,
#  'newsarama': 11788,
#  'survival': 16266,
#  'kit': 9708,
#  'whistle': 18359,
#  'starter': 15914,
#  'wire': 18450,
#  'saw': 14870,
#  'cree': 4489,
#  'torch': 17027,
#  'blanket': 2807,
#  'knife': 9751,
#  '2oroyunym2': 420,
#  'c9jnxz3dxc': 3317,
#  'babybackreeve': 2299,
#  'fatality': 6463,
#  'drunk': 5554,
#  'meals': 10876,
#  '101': 108,
#  'what': 18333,
#  'cook': 4319,
#  'when': 18345,
#  'totally': 17047,
#  'obliterated': 12172,
#  'wj0u59mppb': 18480,
#  'wolforth': 18521,
#  'single': 15370,
#  'middle': 11062,
#  'fourth': 6874,
#  'hit': 8131,
#  'night': 11845,
#  'altamonte': 1675,
#  'springs': 15812,
#  'china': 3794,
#  'stock': 15994,
#  'market': 10744,
#  'crash': 4458,
#  'there': 16744,
#  'gems': 7230,
#  'rubble': 14623,
#  'pe2r3ln16o': 12825,
#  'by': 3280,
#  'forbes': 6817,
#  'igmpj': 8553,
#  'aren': 1936,
#  'dangling': 4759,
#  'piercing': 13001,
#  'crystals': 4554,
#  'potentially': 13247,
#  'hazardous': 7908,
#  'eyes': 6328,
#  'light': 10206,
#  'recent': 14020,
#  'events': 6179,
#  'like': 10220,
#  'say': 14871,
#  'screams': 14952,
#  'five': 6682,
#  'southeast': 15702,
#  'dirt': 5220,
#  'riot': 14398,
#  'series': 15094,
#  'crowns': 4531,
#  'champions': 3678,
#  'championsblackfoot': 3679,
#  'id': 8507,
#  'v9i4pfxo0c': 17764,
#  'emotional': 5927,
#  'wreck': 18622,
#  'right': 14383,
#  'now': 12008,
#  'dat': 4797,
#  'liable': 10172,
#  'fuck': 7012,
#  'four': 6872,
#  'technologies': 16552,
#  'humans': 8353,
#  'survive': 16267,
#  'environmental': 6030,
#  'disaster': 5232,
#  '4rtpjrhsqe': 670,
#  'allah': 1631,
#  'describes': 5050,
#  'piling': 13011,
#  'wealth': 18237,
#  'thinking': 16778,
#  'last': 9980,
#  'forever': 6833,
#  'description': 5052,
#  'people': 12864,
#  'hellfire': 8005,
#  'surah': 16242,
#  'humaza': 8354,
#  'reflect': 14077,
#  'amazing': 1695,
#  'footage': 6811,
#  'lightning': 10212,
#  'filmed': 6616,
#  'while': 18352,
#  'lifting': 10204,
#  'chicago': 3769,
#  'aog5chjmvs': 1842,
#  'cln2sxzy1z': 3971,
#  'another': 1804,
#  'day': 4826,
#  'excellent': 6219,
#  '_dangerousbeans': 1181,
#  'porridge': 13216,
#  'seriously': 15096,
#  'orange': 12439,
#  'phenomenal': 12948,
#  'kick': 9642,
#  'hendrixonfire': 8023,
#  'blackcats': 2788,
#  'big': 2692,
#  'noob': 11940,
#  'conquest': 4254,
#  'mixed': 11196,
#  'violated': 17936,
#  'dr': 5461,
#  'limit': 10236,
#  'server': 15100,
#  'max': 10826,
#  'shed': 15201,
#  'innocent': 8804,
#  'their': 16719,
#  'sons': 15654,
#  'daughters': 4806,
#  'land': 9945,
#  'was': 18164,
#  'polluted': 13192,
#  'psalms': 13494,
#  '106': 114,
#  '38': 495,
#  'help': 8013,
#  'stop': 16009,
#  'sin': 15363,
#  'abortion': 1281,
#  'stolen': 16001,
#  'national': 11659,
#  'guard': 7636,
#  'armory': 1967,
#  'albany': 1589,
#  'still': 15987,
#  'missing': 11172,
#  'gunsense': 7672,
#  'lknu8902je': 10314,
#  'too': 17011,
#  'dangerous': 4758,
#  'them': 16726,
#  'ok': 12298,
#  'rest': 14268,
#  'us': 17654,
#  'danger': 4757,
#  'yl67dkf4tb': 18980,
#  'tailor': 16412,
#  'fucking': 7017,
#  'made': 10613,
#  'double': 5432,
#  'play': 13096,
#  'kay': 9539,
#  'robbed': 14456,
#  'burned': 3236,
#  'popcorn': 13203,
#  'ashberxo': 2026,
#  'mind_mischief': 11112,
#  'removal': 14160,
#  'traces': 17091,
#  'something': 15643,
#  'obliteration': 12173,
#  'blazing_ben': 2818,
#  'pattyds50': 12776,
#  'gwfrazee': 7696,
#  'joshuaassaraf': 9337,
#  'not': 11980,
#  'really': 13994,
#  'sadly': 14737,
#  'come': 4126,
#  'expect': 6260,
#  'obama': 12159,
#  'freediscountbks': 6938,
#  'desolation': 5068,
#  'run': 14645,
#  'till': 16879,
#  'axvqldtehc': 2243,
#  'thriller': 16824,
#  'suspense': 16280,
#  'kindle': 9684,
#  'amreading': 1726,
#  'msmigot': 11444,
#  'wow': 18594,
#  'convincing': 4317,
#  'compelling': 4177,
#  'evidence': 6195,
#  'change': 3687,
#  'view': 17913,
#  'climate': 3958,
#  'deniers': 5009,
#  'tend': 16595,
#  'giving': 7353,
#  'kg5plkedhr': 9621,
#  'wrapup': 18620,
#  'cable': 3326,
#  'tv': 17314,
#  'companies': 4171,
#  'shares': 15183,
#  'crushed': 4543,
#  'after': 1471,
#  'disney': 5263,
#  'disappoints': 5231,
#  'qeihvn3dnq': 13654,
#  'printable': 13379,
#  'templates': 16588,
#  'naex0q1ax0': 11611,
#  'marketforce': 10747,
#  'perth': 12902,
#  'named': 11623,
#  'winner': 18441,
#  'sirens': 15389,
#  'round': 14562,
#  'iinet': 8580,
#  'nbn': 11693,
#  'buffering': 3193,
#  'cat': 3551,
#  'shark': 15188,
#  'radio': 13834,
#  'spot': 15799,
#  'ggperglvki': 7293,
#  'aminespn': 1717,
#  'mencius': 10948,
#  'tears': 16543,
#  'worse': 18578,
#  'correct': 4359,
#  'takes': 16422,
#  'explosion': 6287,
#  'pain': 12639,
#  'usfs': 17679,
#  'acronym': 1351,
#  'united': 17553,
#  'states': 15926,
#  'service': 15102,
#  '8nadrgr4xc': 1043,
#  'morgan': 11346,
#  'silver': 15344,
#  'dollar': 5383,
#  '1880': 210,
#  'gem': 7225,
#  'bu': 3175,
#  'dmpl': 5347,
#  'cameo': 3388,
#  'rev': 14304,
#  'blazing': 2817,
#  'ms': 11435,
#  'grade': 7512,
#  'read': 13969,
#  'm96kbqwior': 10580,
#  'wrjr846fks': 18638,
#  'take': 16417,
#  'away': 2229,
#  'preservation': 13334,
#  'parks': 12717,
#  'imposition': 8663,
#  'african': 1462,
#  'never': 11769,
#  'imagined': 8625,
#  'gi2p9tuvbi': 7310,
#  'vince': 17928,
#  'mcmahon': 10863,
#  'billionaire': 2719,
#  'remember': 14146,
#  'reading': 13972,
#  'deluge': 4974,
#  'posts': 13245,
#  'about': 1282,
#  'losing': 10422,
#  '350': 477,
#  'ko0oz3ryfg': 9773,
#  'almusafirah_': 1657,
#  'feel': 6527,
#  'innit': 8803,
#  'charminar': 3720,
#  'demolish': 4991,
#  'if': 8537,
#  'falling': 6407,
#  'state': 15923,
#  'anyway': 1837,
#  'engineers': 5987,
#  'opinion': 12408,
#  'telangana': 16568,
#  'nepd_loyko': 11755,
#  'texans': 16637,
#  'hope': 8225,
#  'wrong': 18641,
#  'houston': 8276,
#  'him': 8109,
#  'foster': 6862,
#  'injury': 8795,
#  'hse': 8309,
#  'releases': 14127,
#  'annual': 1800,
#  'workplace': 18561,
#  'facilities': 6372,
#  'data': 4798,
#  'h4usheekxm': 7737,
#  'jnhnx3oisn': 9276,
#  'engineermatarai': 5986,
#  'ate': 2095,
#  'mataas': 10795,
#  'kc': 9545,
#  'rating': 13919,
#  'they': 16765,
#  'did': 5164,
#  'think': 16777,
#  'doing': 5380,
#  'along': 1661,
#  'ratings': 13920,
#  'ovofest': 12568,
#  'drake': 5473,
#  'straight': 16032,
#  'bagging': 2330,
#  'meek': 10911,
#  'ovo': 12567,
#  'stage': 15878,
#  'ziphimup': 19178,
#  'ignition': 8555,
#  'knock': 9757,
#  'detonation': 5099,
#  'sensor': 15072,
#  'senso': 15071,
#  'standard': 15889,
#  'ks111': 9820,
#  'nxleiijfgs': 12091,
#  'xsgwm5zxpd': 18812,
#  'withering': 18468,
#  'death': 4868,
#  'album': 1593,
#  'found': 6868,
#  'undermine': 17515,
#  'his': 8128,
#  'backyard': 2312,
#  'because': 2528,
#  'inundated': 8899,
#  'floor': 6745,
#  'mustering': 11522,
#  'food': 6802,
#  'slayer': 15482,
#  'reflects': 14080,
#  'low': 10452,
#  'mayhem': 10835,
#  'festival': 6564,
#  'attendance': 2127,
#  'king': 9690,
#  'diamond': 5150,
#  'jeff': 9186,
#  'hanneman': 7821,
#  'passing': 12743,
#  '6n6gcej9iy': 845,
#  'liked': 10222,
#  'youtube': 19029,
#  'video': 17905,
#  'chaboyyhd': 3663,
#  'yr67ugesrm': 19043,
#  'battlefield': 2445,
#  'funny': 7046,
#  'moments': 11296,
#  'dukes': 5591,
#  'undercover': 17510,
#  'soldier': 15623,
#  'pandemonium': 12673,
#  'aba': 1245,
#  'woman': 18525,
#  'delivers': 4968,
#  'without': 18470,
#  'face': 6366,
#  'photos': 12974,
#  'c5u9qsysej': 3310,
#  'turkish': 17299,
#  'couple': 4402,
#  'spent': 15759,
#  'wedding': 18253,
#  'feeding': 6525,
#  '4000': 579,
#  'syrian': 16356,
#  'refugees': 14082,
#  'got': 7477,
#  'marrie': 10763,
#  'igll3ph6o1': 8550,
#  'oh': 12268,
#  'teamhennessy': 16534,
#  'nj': 11869,
#  'tprimo24': 17080,
#  'happy': 7834,
#  'birthday': 2748,
#  'djeddygnj': 5318,
#  'colombian': 4103,
#  'mrv54fidfn': 11432,
#  'rosemarytravale': 14547,
#  'do': 5357,
#  'use': 17673,
#  'same': 14791,
#  'weapon': 18239,
#  'cause': 3576,
#  'might': 11073,
#  'screwed': 14959,
#  'xd': 18750,
#  'question': 13741,
#  'anybody': 1832,
#  'else': 5884,
#  'having': 7896,
#  'problem': 13398,
#  'circle': 3872,
#  'epicentre': 6048,
#  'dspws6hj8w': 5566,
#  'heart': 7962,
#  'racing': 13829,
#  'temperature': 16586,
#  'through': 16827,
#  'roof': 14534,
#  'videoveranomtv': 17909,
#  'fifth': 6596,
#  'harmony': 7856,
#  'zimmerman': 19172,
#  'fan': 6421,
#  'club': 3996,
#  'twitter': 17347,
#  'rzimmermanjr': 14693,
#  'renewsit': 14172,
#  'reduced': 14066,
#  'her': 8029,
#  'sock': 15606,
#  'acc': 1307,
#  'ybshleie3p': 18914,
#  'generation': 7236,
#  'lt': 10477,
#  'things': 16775,
#  'getting': 7271,
#  'caught': 3574,
#  'dust': 5615,
#  'storm': 16021,
#  'challenging': 3675,
#  'real': 13977,
#  'estate': 6117,
#  'common': 4160,
#  'jf5ft5cq9j': 9222,
#  'gix1gaynxz': 7354,
#  'p93s2rfhx6': 12609,
#  'crackdown': 4444,
#  'uses': 17678,
#  'multiple': 11484,
#  'servers': 15101,
#  'multiplayer': 11483,
#  'can': 3410,
#  'whole': 18372,
#  'copped': 4337,
#  'sweater': 16306,
#  'stretcher': 16066,
#  'natz5ipv1x': 11670,
#  'leaeby6cr2': 10051,
#  'save': 14859,
#  'beautiful': 2520,
#  'town': 17071,
#  'ontario': 12373,
#  'destruction': 5085,
#  'power': 13261,
#  'plant': 13086,
#  'developer': 5109,
#  'hld5xlywbn': 8144,
#  'graysondolan': 7540,
#  'only': 12369,
#  'drown': 5540,
#  'job': 9279,
#  'opening': 12399,
#  'downtown': 5451,
#  'center': 3629,
#  'seattle': 14995,
#  'chemical': 3751,
#  'dependency': 5023,
#  'counselor': 4392,
#  'intern': 8869,
#  'jobs': 9283,
#  'bnrdkgxavr': 2900,
#  'domestic': 5391,
#  'ifs': 8544,
#  'ands': 1753,
#  'buts': 3264,
#  'created': 4478,
#  'gop': 7467,
#  'hfgjgfgfel': 8052,
#  'aannnnd': 1237,
#  'quarantine': 13723,
#  'offensive': 12232,
#  'p1jlurgwbu': 12592,
#  'wonder': 18533,
#  'cool': 4322,
#  'weird': 18276,
#  'll': 10317,
#  'characters': 3701,
#  'mkx': 11220,
#  'skinless': 15444,
#  'predator': 13306,
#  'human': 8347,
#  'history': 8130,
#  'becomes': 2535,
#  'race': 13825,
#  'between': 2645,
#  'catastrophe': 3555,
#  'servicin': 15104,
#  'section': 15008,
#  'lurkin': 10514,
#  'beyonce': 2650,
#  'pick': 12982,
#  'thoyhrhkfj': 16808,
#  'army': 1969,
#  'beyhive': 2649,
#  'wvj39a3bgm': 18668,
#  'upon': 17623,
#  'time': 16883,
#  'fact': 6376,
#  'decided': 4889,
#  'go': 7417,
#  'university': 17557,
#  'hours': 8269,
#  'actually': 1375,
#  'sunk': 16202,
#  'gloriavelez': 7389,
#  'gm': 7399,
#  'pray': 13293,
#  'any': 1830,
#  'attack': 2118,
#  'enemy': 5980,
#  'derail': 5036,
#  'ur': 17640,
#  'destiny': 5077,
#  'blocked': 2849,
#  'lord': 10407,
#  'floods': 6744,
#  'heavenly': 7975,
#  'blessings': 2829,
#  'okay': 12302,
#  'am': 1687,
#  'vcv73buacz': 17822,
#  'homemade': 8196,
#  'frozen': 6992,
#  'yogurt': 18997,
#  'pops': 13207,
#  'had': 7760,
#  'luck': 10489,
#  'yzazf4ceoa': 19084,
#  'x5rc5nuamh': 18727,
#  'np': 12016,
#  'avenged': 2201,
#  'sevenfold': 15120,
#  'hail': 7769,
#  'ladyfleur': 9919,
#  'example': 6214,
#  'even': 6176,
#  'cafì': 3342,
#  'trying': 17254,
#  'itself': 9014,
#  'hashtag': 7875,
#  'hijacking': 8094,
#  'flood': 6741,
#  'combo': 4122,
#  '53inch': 711,
#  '300w': 453,
#  'curved': 4616,
#  'led': 10074,
#  'work': 18554,
#  'bar': 2380,
#  '4x4': 685,
#  'offroad': 12253,
#  'fog': 6786,
#  'lamp': 9936,
#  '5xmce6jufs': 776,
#  '3zo7px3p1v': 575,
#  'marijuana': 10733,
#  'critical': 4513,
#  'research': 14230,
#  'treating': 17159,
#  'ptsd': 13514,
#  't6fuahfp7p': 16378,
#  'hempoil': 8020,
#  'cannabis': 3430,
#  'rhe7dxm7ey': 14345,
#  'official': 12242,
#  'vid': 17903,
#  'thereal': 16745,
#  'gt': 7624,
#  '4i0rjc9rqu': 646,
#  'trubgme': 17235,
#  'comin': 4134,
#  'soon': 15657,
#  'cars': 3520,
#  'those': 16801,
#  'cyclists': 4665,
#  'going': 7438,
#  'past': 12747,
#  'scratching': 14947,
#  'pedals': 12837,
#  'should': 15274,
#  'c4news': 3306,
#  'throw': 16829,
#  'water': 18184,
#  'until': 17596,
#  'words': 18553,
#  'choke': 3807,
#  'tube4nbqnz': 17277,
#  'lawsonofficial': 10022,
#  'just': 9417,
#  'followed': 6792,
#  'cannot': 3432,
#  'contain': 4279,
#  'joy': 9345,
#  'thankyou': 16676,
#  '34': 475,
#  '22': 340,
#  'redeemeth': 14053,
#  'soul': 15681,
#  'servants': 15097,
#  'none': 11936,
#  'trust': 17247,
#  'shall': 15163,
#  'desolate': 5067,
#  'harder': 7846,
#  'conflict': 4236,
#  'glorious': 7390,
#  'triumph': 17209,
#  'thomas': 16794,
#  'paine': 12640,
#  'owner': 12573,
#  'area': 1934,
#  'gay': 7188,
#  'admits': 1408,
#  'arson': 1990,
#  'scheme': 14914,
#  'myhohvrhil': 11560,
#  'lgbt': 10157,
#  'tm5hthfdo0': 16936,
#  'act': 1354,
#  'age': 1488,
#  'mess': 10974,
#  'everyone': 6190,
#  'wild': 18398,
#  'fun': 7035,
#  'videos': 17908,
#  'russian': 14665,
#  'customs': 4623,
#  'total': 17043,
#  '319': 466,
#  'tons': 17002,
#  'today': 16964,
#  'phew': 12949,
#  'italian': 9003,
#  'meats': 10887,
#  'were': 18293,
#  'incinerator': 8697,
#  'pulkovo': 13534,
#  'airport': 1544,
#  'sean': 14983,
#  'end': 5965,
#  'career': 3485,
#  'sg': 15141,
#  'blizzard': 2839,
#  'vs': 18039,
#  'knockout': 9760,
#  ...}

# %%
# Dataframe of bag_of_word grouped by tweets that support real disaster and tweets that does not. 
bag_of_words = pd.DataFrame(bag_of_words, columns=vectorizer.get_feature_names())
bag_of_words.index = df_train_grouped.index
bag_of_words
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-0f93e7106bca> in <module>()
#       1 # Dataframe of bag_of_word grouped by tweets that support real disaster and tweets that does not.
# ----> 2 bag_of_words = pd.DataFrame(bag_of_words, columns=vectorizer.get_feature_names())
#       3 bag_of_words.index = df_train_grouped.index
#       4 bag_of_words
#
# NameError: name 'bag_of_words' is not defined

# %%
# Using TfidfVectorizer
vectorizer = TfidfVectorizer()
bag_of_words = vectorizer.fit_transform(corpus).todense()

# DataFrame
bag_of_words = pd.DataFrame(bag_of_words, columns=vectorizer.get_feature_names())
bag_of_words
# Out:
#          00       000      0000  ...     ûóher    ûókody  ûónegligence
# 0  0.002068  0.000517  0.000000  ...  0.000000  0.000000      0.000000
# 1  0.005380  0.000269  0.000378  ...  0.000378  0.000378      0.000378
#
# [2 rows x 19330 columns]

# %%
# Here we can do some more text statistics
